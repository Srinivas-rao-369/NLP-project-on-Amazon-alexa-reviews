# %%
import pandas as pd

# %%
data = pd.read_csv('amazon_alexa.tsv', sep = '\t')

# %%
data
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback
# 0                                         Love my Echo!         1
# 1                                             Loved it!         1
# 2     Sometimes while playing a game, you can answer...         1
# 3     I have had a lot of fun with this thing. My 4 ...         1
# 4                                                 Music         1
# ...                                                 ...       ...
# 3145  Perfect for kids, adults and everyone in betwe...         1
# 3146  Listening to music, searching locations, check...         1
# 3147  I do love these things, i have them running my...         1
# 3148  Only complaint I have is that the sound qualit...         1
# 3149                                               Good         1
#
# [3150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['rating', 'date', 'variation', 'verified_reviews', 'feedback'], dtype='object')

# %%
data['feedback'].value_counts()
# Out:
# 1    2893
# 0     257
# Name: feedback, dtype: int64

# %%
data.corr()
# Out:
#             rating  feedback
# rating    1.000000  0.861968
# feedback  0.861968  1.000000

# %%
data = data[['verified_reviews', 'rating']]

# %%
data
# Out:
#                                        verified_reviews  rating
# 0                                         Love my Echo!       5
# 1                                             Loved it!       5
# 2     Sometimes while playing a game, you can answer...       4
# 3     I have had a lot of fun with this thing. My 4 ...       5
# 4                                                 Music       5
# ...                                                 ...     ...
# 3145  Perfect for kids, adults and everyone in betwe...       5
# 3146  Listening to music, searching locations, check...       5
# 3147  I do love these things, i have them running my...       5
# 3148  Only complaint I have is that the sound qualit...       5
# 3149                                               Good       4
#
# [3150 rows x 2 columns]

# %%
import nltk

# %%
from nltk import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
stopwords_list = set(stopwords.words('English'))

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
ps = PorterStemmer()
lmt = WordNetLemmatizer()

# %%
import re

# %%
clean_reviews_list = []

# %%
words = ['alexa', 'bluetooth', 'cellphone', 'ipad', 'bedroom', 'house', 'home', 'light', 'dinosaur', 'amazon', 'spotify',
        'computer', 'kitchen', 'daughter', 'father', 'mother', 'sister', 'brother', 'elder', 'ship', 'product', 'plus' 'minus'
        'household', 'new', 'member', 'color', 'wife', 'st', 'etc', 'tube', 'family', 'prime', 'day']
for each_review in range(len(data)):
    current_review = data['verified_reviews'].values[each_review]
    current_review = re.sub('[^a-zA-Z]', ' ', current_review)
    list_of_words = word_tokenize(current_review)
    clean_review = ''
    for each_word in list_of_words:
        each_word = each_word.lower()
        if not each_word in stopwords_list:
            if not each_word in words:
                each_word = ps.stem(each_word)
                clean_review = clean_review + ' ' + each_word
    clean_reviews_list.append(clean_review)

# %%
clean_reviews_list
# Out:
# [' love echo',
#  ' love',
#  ' sometim play game answer question correctli say got wrong answer like abl turn light away',
#  ' lot fun thing yr old learn dinosaur control light play game like categori nice sound play music well',
#  ' music',
#  ' receiv echo gift need anoth someth play music easili access found smart speaker wait see els',
#  ' without use mani featur see use great alarm u r almost deaf hear alarm live room reason enough keep fun ask random question hear respons seem smartbon polit yet',
#  ' think th one purchas work get one everi room realli like featur offer specifili play music echo control light throughout',
#  ' look great',
#  ' love listen song heard sinc childhood get news weather inform great',
#  ' sent year old dad talk constantli',
#  ' love learn knew thing eveyday still figur everyth work far easi use understand make laugh time',
#  ' purchas knee problem give someth tri come get around fast like enjoy littl big thing play song time cook',
#  ' love love love',
#  ' expect',
#  ' love hate',
#  ' realli happi purchas great speaker easi set',
#  ' use coupl day lot fun toy like household tri learn differ featu benefit come',
#  ' love size nd gener echo still need littl improv sound',
#  ' like origin echo shorter greater fabric choic miss volum ring top plu minu button big deal ring w comfort well like use standard usb charger port instead previou round pin guess sound seem work still answer echo like',
#  ' love echo good music sound play understand command difficult time find specif playlist song good music lack major program',
#  ' love use play music play radio itun play podcast anypod set remind listen flash brief news weather everi morn reli custom list like abl voic control volum sure continu find use sometim bit frustrat understand say',
#  ' set day still ad smart devic speaker great play music like size station counter intrus look',
#  ' love play sleep sound immedi ask',
#  ' got second unit expect sound improv didnt realli see differ overal big improv gener',
#  ' amaz',
#  ' love echo easi oper load fun everyth advertis use mainli play favorit tune test knowledg',
#  ' sound great love',
#  ' fun item play get use use sometim hard time answer question ask think better',
#  ' like one',
#  ' still learn capabl far pretti pretti pretti good',
#  ' like',
#  ' work well need learn command uniqu owner user like learn tasha birthday learn definit fine great',
#  ' speaker sound pretti good small setup pretti easi bought two reason rate follow instruct synch music unit know done correctli sync primari motiv purchas multipl unit',
#  ' devic awesom',
#  ' bought compar speaker qualiti first gener speaker like sound better though like fact first gener chargeabl base bought keep mobil need better sound',
#  ' love echo still learn thing abl follow instruct includ packag found great one u',
#  ' speaker better gener echo',
#  ' thing way cool get one want cool',
#  ' first digit assist give good review speaker realli good cheap price fun play use alarm clock go get first place end echo go one definit tri like best number devic connect purchas came smart plug connect lamp turn light',
#  ' husband like abl use listen music wish knew capabl',
#  ' android would allow connect fortun appl cell hour tech support fix glitch run',
#  ' far good',
#  ' tri play certain broadway show like camelot give ne group camelot',
#  ' great',
#  ' satisfi echo control light room listen jimmi buffet ask',
#  ' like siri fact siri answer accur see real need household though good bargain deal',
#  ' love echo still learn everi thing work ton fun',
#  ' love much',
#  ' differ appl play specif list music must plu account must pay play music star reason everyth els',
#  ' excelent lo unico es que esta en espa ol',
#  ' still learn use far echo great sound actual much better expect',
#  ' work expect also good sound qualiti consid price sale featur',
#  ' sound echo nd gener phenomen mention love help',
#  ' like googl better',
#  ' let play learn get',
#  ' work advertis easi setup still learn',
#  ' great sound easi set',
#  ' love bought other friend',
#  ' love echo purchas compani husband great say name tell joke play favorit song',
#  '',
#  ' love abl listen music easili still learn featur avail',
#  ' realli know could use devic use thing need overview',
#  ' love wish built hub',
#  ' use primarili play music work wonder still get use mani thing sent sever tip sinc got thank help',
#  ' easi set',
#  ' fast respons amaz clear concis answer sound qualiti fantast still get use alexia usd echo full extent',
#  ' need na na nana',
#  ' everyth expect',
#  ' love echo work like said would smart speak function everyth els good',
#  ' great sound small packag easi set use fun',
#  ' work sound great',
#  ' sound amaz mani collect music',
#  ' set',
#  ' alway listen',
#  ' awesom',
#  ' bought control fio televis work well hope time control fio discov thing play music ask great sound play game play radio station play old time radio program like long ranger mani app add abil play madlib great fun also control household applianc purchas compat power strip control light fan tv compon look forward implement control also add compon chosen music play room compon locat',
#  ' speaker excel sound work perfectli',
#  ' like',
#  ' love everyth',
#  ' littl nervou receiv echo realli tech savvi found bit intimid first take long figur happi purchas think ad echo spot',
#  ' like still learn use',
#  ' great technolog believ speaker volum qualiti wonder wish bought anoth one',
#  ' purchas echo dot husband father use constantli hear qualiti sound echo nd gener brainer best gift ever',
#  ' work fine',
#  '',
#  ' clear music',
#  ' fun use good sound qualiti',
#  ' echo work well abl sync music devic',
#  ' work great think charg anoth cent unlimit music buy echo',
#  ' alreadi echo dot echo even better fuller sound also setup let phone call made contact list great',
#  ' speaker sound realli good',
#  ' good sound work well',
#  ' love savvi support help patient',
#  ' love think get one discount offer could pass fun ask play song group come playlist music also connect iphon play music pandora youtub video use speaker fun ask differ type question inform like weather news even time countri downsid limit data wifi plan use burn play music',
#  ' like far lot tri yet',
#  ' love use strictli music great',
#  ' love echo love size materi speaker qualiti hook one easili work addit light thermostat next echo dot lot echo think traffic weather trivia',
#  ' love',
#  ' entir love echo part',
#  ' great fun get know function wow fun homework help talk grandchildren also echo huge bonu wait learn',
#  ' love',
#  ' awesom thing love',
#  ' work exactli expect speaker great sound perfect classroom',
#  ' love love littl gadget made live much easier like person secretari live hardli need cd anymor sinc play everyth need go get dot soon room thank',
#  ' speaker surpris qualiti happi purchas',
#  ' easi set work wonder love',
#  ' realli impress sound qualiti play music devic bass sound almost like come bigger speaker prop',
#  ' still great sound qualiti seem wors get wrong definit get use within hour definit feel like echo gen sound qualiti better besid great addit abl play wifi even better',
#  ' outlet work disappoint',
#  ' great devic respons help',
#  ' sound terribl u want good music get bose',
#  ' like sound troubl paid extra money access million song sometim work ex play italian song understand play opera tosca respons sorri',
#  ' easi set use bad plug would nice take outsid oper batteri recharg',
#  ' still learn way use real hit grandkid ask play music danc yr cute',
#  ' star gener like great ask like play music set timer make call reason rate sometim connect die echo stop play music show red ring seem connect issu overal great',
#  ' work great upgrad echo dot full size echo happier',
#  ' els say',
#  ' upgrad lilttl echo dot happi sound',
#  ' excel set eas well',
#  ' first gen echo sinc first came work well purchas nd gen far happi seem improv speaker provid enhanc sound music',
#  ' love echo smart speaker love volum clariti easi set wonder gift age',
#  ' wonder fast deliveri',
#  ' initi harder set call tech knowledg work great',
#  ' easi set love',
#  ' great sound respons voic command',
#  ' live long without echo get enjoy music style ask go gread wireless love echo love',
#  ' cool speaker sound good blast',
#  ' much fun love abl listen music across room busi someth els',
#  ' far seem nice item pick voic understand without problem ask turn music next room heard fine use listen music check weather done thing well',
#  ' love echo',
#  ' love help use rememb thing sleep ask anyth week still learn',
#  ' better gen everi way except one realli miss ring top volum control quicker easier grab top twist without look button find one press time also wish bass bit better great devic happi',
#  ' love',
#  ' far like',
#  ' thoroughli enjoy ecoo love read audiobook offic simpli open audiobook kindl continu elsewher wonder listen music mood book great set remind much',
#  ' still love',
#  ' love',
#  ' love sound qualiti unit clear sound',
#  ' listen talk radio morn turn light system excel job full sound system stream siriu',
#  ' week still learn learn process love music call time listen podcast radio station start keep shop list groceri list love search paper pencil get time temperatur great wait weather report sound good fussi woofer tweeter base echo fine afternoon go tri drop son get go surpris',
#  ' much featur',
#  ' great sound qualiti great featur great multi room music cool',
#  ' cool',
#  ' everyon echo two three bought echo qvc',
#  ' annoy everyth show abl download spend much time tri figur phrase machin may well look',
#  ' sinc begin accident spill water replac nd gener decid without echo setup easi work within minut',
#  ' like abl tell alexia music want hear sometim troubl find song specif titl',
#  ' like look better origin echo move old echo basement room nice sound',
#  ' echo wonder still learn use music request somewhat limit',
#  ' know half thing ask recogn sprinkler wifi control even though detail say compat program chang wifi thermostat set match wifi router handi music player music',
#  ' love',
#  ' awesom understand kid',
#  ' pleasantli surpris sound qualiti mani featur nice easili hear particular artist hear book simpl command look forward explor option devic',
#  ' met exceed expect easi set realli quick respons',
#  ' like fact get kind music want request like inform photo littl pamphlet wish includ connect tv command realli love music',
#  ' found way access echo thorough account think part top line video music also think setup app defin exampl music like well integr echo tri ask playlist echo sure even though set play list set also like fact word exact match playlist name never rememb like readi natur echo respond queri',
#  ' great item ad audibl book make even better thank',
#  ' nd gen echo sale resist begin smart set happier say done amaz job connect smart devic thank control light smart plug tv troubl connect echo wifi phone app work perfectli fine let add skill routin smart devic timer much sound qualiti good enough sinc audiophil hear voic even watch movi high volum design great modern definit add nice touch chang cover like sale overal great addit enabl mani possibl yet sure add',
#  ' versatil fun',
#  ' work great killer speaker son love',
#  ' regret wait long purchas item surpris pleas sound qualiti',
#  ' stop work week follow command realli fun work',
#  ' far love work get thing set love groceri list app',
#  ' perform pretti much expect disappoint provid terminolog need play variou kind music without subscrib music servic understand music choic may limit without know ask access music provid free along echo purchas chart show languag need use',
#  ' easi set',
#  ' like except speaker high qualiti expect',
#  ' great invest help made laugh',
#  ' yet anoth exho love',
#  ' love plan gender music big band jazz easi find local radio sound good stop voic command get phone call',
#  ' good valu',
#  ' super easi set love echo',
#  ' what like speaker ask',
#  ' best gift dad joke mom one listen repeat stori go forward',
#  ' great addit breakfast room tune inform instantli avail slowli learn featur',
#  ' sound qualiti',
#  ' sad joke worthless',
#  ' entertain',
#  ' good qualiti',
#  ' work great sound great miss beat wish batteri better portabl',
#  ' love till someon stole afford replac yet go',
#  ' rock',
#  ' got gift love never would bought one allow play music amozon music worth also give brief tell joke',
#  '',
#  ' mom bought echo dot repeat ask take one great told two day made take hour later could live life without amaz four larg speaker small echo dot return say go order speaker go big get echo otherwis tou return two echo dot live without',
#  ' love great',
#  ' easi set user friendli',
#  ' realli disappoint plug wall socket time fault check made assumpt compani technolog advanc would sell recharg batteri could return would appl music boom speaker give flexibl',
#  ' think nd gen sound good aux could add extern speaker go get dot nd issu uniqu unit understand overrid default prevent play blue tooth speaker play group get delay use bt speaker unit heard abl play group use bt speaker',
#  ' everyth',
#  ' like interact ask question like ask setup schedul connect lamp',
#  ' supberb sound definit worth extra money listen lot music',
#  ' realli love echo think sound qualiti great lot fun realli handi music get updat weather sport',
#  ' love grandkid',
#  ' far work well alway intuit link differ devic skill get hang',
#  ' work advertis',
#  ' love',
#  ' love addit speaker qualiti great love two complaint suggest futur seri would better commun abil exampl smart light unless specifi prior command either respond say recogn may want respond say thank afterward repeat thank time respond husband know sound odd laugh mayb southern thing want manner',
#  ' like everyth music trivia game weather',
#  ' describ receiv time like automat enrol music',
#  ' great devic',
#  ' own echo overa year lack easi way increas decreas volum without tell increas decreas volum hard sinc english second languag born korea sound echo superb keep',
#  ' love work well',
#  ' nice impress wish say though',
#  ' love nice easi access much info',
#  ' got great sound bass work time still hot miss recogn thing',
#  ' still discov echo',
#  ' amaz paroduct',
#  ' good hear rang sound qualiti bit complic set quit understand lot even speak slowli clearli love flash brief featur interfac abod secur system',
#  ' speaker sound good',
#  ' absolut love',
#  ' best part control thermostat light anyth dislik',
#  ' thoroughli enjoy echo instal easi use app purchas kasa smart plug control live room light instal easi use kasa app sinqu right echo enjoy play music echo sound qualiti awesom ad kasa smart bulb setup seamless look forward ad autom',
#  ' entertain',
#  ' cool easi setup fun use sound qualiti much better anticip',
#  ' love great sound easi connect use',
#  ' work fairli smart tv mainli tv manufactur lg fault due support anyth older tv year smart lock also need addit piec equip order connect well speaker sound great work well',
#  ' great sound littl speaker',
#  ' enjoy',
#  '',
#  ' cool',
#  ' good qualiti great sound qualiti',
#  ' work perfectli',
#  ' great sometim understand command fire tv fabul speaker',
#  ' love echo great sound smart',
#  ' sure love',
#  ' play great',
#  ' work absolut great',
#  ' amaz great sound qualiti',
#  ' best thing invest thank much',
#  ' extrem impress item bought warehous outlet minor imperfect tell even one work great come packag seal damag miss anyth like sound qualiti see knock bose great easi use minor learn curv learn voic integr seamlessli servic wait get classroom lot fun even speaker let alon plan',
#  ' love echo show wonder music info sleep sound',
#  ' awesom life changer serious abl start morn wake alarm play music gotten use voic anoth room listen say love echo hesit get one price speaker unbeliev buy cordless holder take echo anywher love purchas love',
#  ' super impress laps play anyth smart enough differenti among account use either randomli speak nobodi talk today unplug sure ever use',
#  ' like everyth',
#  ' like',
#  ' never issu buy use electron long get good like read comment see use',
#  ' realli love echo',
#  ' bought love',
#  ' fun got today pod go car use',
#  ' like',
#  ' third echo worth everi penni like household employe small flat rate keep bedroom live room drop use intercom listen music answer quick question alarm wake school',
#  ' listen music set timer',
#  ' receiv echo perfect condit devic easi set respond quickli without issu great addit',
#  ' good sound like music schedul like get random thought record think joke cute',
#  ' purchas begin learn far pleas amaz differ action perform enjoy look forward learn option provid',
#  ' echo great other even though smaller',
#  ' funni buy someth look fun wind total use part love',
#  ' bought replac dot live room speaker slightli better hear better tv unfortun understand respond request well dot frequent request time get want dot usual exactli want first request consid upgrad',
#  ' good experi far second gener echo mani thing learn time yet right mostli enjoy music weather updat use alarm featur person also purchas mini smart socket ye excit begin use',
#  ' troubl connect tv exactli tech smart sure one grandson figur far use mostli music',
#  ' simpli love echo hardli watch tv anymor busi listen music speaker pretti goo size fun skill realli make echo fun whole',
#  ' enjoy entir echo experi',
#  ' easi set',
#  ' echo amaz devic mani time seem intuit time ask someth seem clear simpl get result instal fairli straightforward mess sever time simpli thought step complet actual made lose ground figur advic patient app let know move next step biggest issu moment sever echo devic would like use intercom told done howev make echo awar other exist ask answer instruct chang name know like fault would think design would anticip make easier find need instruct small deal mani devic savvi peopl challeng',
#  ' love much',
#  ' origin tap far nd gener best happi see make improv one would great updat littl think would help lot bug happi play music throughout whole adjust bass trebl thank',
#  ' pleas echo nd gener nice avail music weather news probabl lot discov',
#  ' pleasantli surpris sound qualiti echo big fan deep bass might suffici though potenti control option explor evolv smart voic recognit impress stylish fun regret purchas great technic chang peopl ask play song movi respond instantli elderli love one would great gift connect wifi simpl use want unlimit music control sure premium blown away person dj even convers echo embarrass say echo made laugh coupl time ask tell joke tell packag sinc addict come extrem handi',
#  ' easi setup love thing',
#  ' throughout futur arriv',
#  ' alreadi find today could resist get echo also best thing ever use side happier',
#  ' arriv expect',
#  ' bought week ago everyth excel forget buy charger order must take outsid pool worri hire electrician put outlet yard',
#  ' terrif',
#  ' love echo',
#  ' smaller origin look nicer',
#  ' work great',
#  ' husband would call late adopt come technolog decid would tri echo serv primarili music sourc wow amaz great sound also great time listen favorit song buy ask may even buy one elderli dad think enjoy one listen music even place call us',
#  ' realli enjoy chang directv channel play iheartradio pandora adjust ac thermostat turn live room light outsid light',
#  ' want one bought absolut love',
#  ' glad got echo speaker much stuff non smart speaker person love timer featur help cook multipl thing simultan pandora integr anoth featur use daili happi purchas get echo hub echo dot futur',
#  ' see subject line love',
#  ' love',
#  ' easi setup',
#  ' hesit buy echo echo dot seem good enough echo except sound qualiti realli feel need howev glad got differ sound realli far superior echo dot listen greatest showman littl power',
#  ' sound qualiti great still learn differ thing fun',
#  ' got good deal work great setup bit pain fault crappi internet servic work great nice sound small speaker',
#  ' love',
#  ' work great perfect offic',
#  ' love one insid one pool good bose speaker around',
#  ' easi use amaz',
#  ' nice',
#  ' love echo total amaz speaker qualiti bum buy two sinc got',
#  ' respons great sound qualiti size',
#  ' effici amaz cool use often everi',
#  ' impress qualiti sound echo definit compar bose mini gave star use appl music account',
#  ' technolog small devic price good sound amaz must featur',
#  ' mainli use music learn time realli noth bad say',
#  ' replac gen concern smaller unit sound wrong anyth volum clear good',
#  ' great addit echo plu',
#  ' best',
#  ' love featur play music everi room multipl echo',
#  ' love surpris much use',
#  ' use enjoy love',
#  ' easi use great sound great purchas great price',
#  ' easi set issu',
#  ' unit add much pleasur echo plu music inform one room',
#  ' extrem use simpl thing like audibl thing like sometim answer everyth ask still nice use',
#  ' difficult set keep time enter password',
#  ' get use use echo use shop list listen music timer work great far',
#  ' cool lot fun use week still learn capabl',
#  ' love love',
#  ' love hard time set app',
#  ' use offic anoth apart music inform',
#  ' great music littl hard figur work',
#  ' given year time birthday gift dad love ask anyth answer plu good homework purchas one bathroom get readi work listen music base metro boom replac clock radio plu echo dot night stand alarm clock',
#  ' impress look clariti sound',
#  ' amaz great speaker',
#  ' still get use connect tv yet thing right use music inform great',
#  ' work sound great bare sf sit counter hear speak room lot function still discov',
#  ' pure fun echo weather joke news brief music still much use lot fun money',
#  ' use time especi commun kid throughout',
#  ' love still learn make lot thing easier like forget turn anoth room ask turn',
#  ' bought turn love especi like call featur sinc cell phone love play music danc music play favorit song sometim lol',
#  ' got wed gift discov featur yet updat play music great though',
#  ' impress sound qualiti',
#  ' pleas purchas echo smart speaker love fact play music differ genr whenev want troubl first wi fi work',
#  ' enjoy eas play music game fun entertain look forward ad smart product',
#  ' second echo love help set timer listen news prepar groceri list get great music',
#  ' sound qualiti good wish could answer question',
#  ' second echo dot speaker weak purchas listen music speaker great',
#  ' great sound',
#  ' great',
#  ' realli use speaker stream music month kinda useless',
#  ' set user friendli set user friendli hope app abl download pc without instal invas driver retir abl instal son suppli smart phone use yet',
#  ' easi set realli enjoy',
#  ' echo come built batteri plug time use make quit inconveni',
#  ' compact bit better origin',
#  ' love pretti cool',
#  ' live room music sound realli good live room hear upstair',
#  ' great set easi sound wonder',
#  ' far like bought music though sound pretti good',
#  ' love',
#  ' love',
#  ' glad bought',
#  ' like type fun music',
#  ' like volum top turn quickli',
#  ' beyond capabl program grandkid lve',
#  ' love echo give hour music help thing difficult set help tekki',
#  ' almost good bose love whole music',
#  ' hardli came',
#  ' easi setup use app also easi instal phone sound qualiti listen music pandora wonder',
#  ' still learn use echo far love',
#  ' work awesom',
#  ' work great',
#  ' small speaker sound great',
#  ' great sound size prize cours',
#  ' echo definit need one',
#  ' great devic seem work better gener',
#  ' item longer work month use connect wifi unrespons reset request',
#  ' love echo dot easi fun get drop grandaught live mile away sound like right next',
#  ' work great differ one',
#  ' one go timer music duti',
#  ' love volum could definit use boost better built speaker would definit star thought ahead put audio auxiliari input bought dedic speaker echo prove best way go',
#  ' work fine',
#  ' work great look brand love echo dot get main room',
#  ' refurbish item work like love easi set love issu volum listen relax fine expect anyth els recommend purchas speaker',
#  ' loud',
#  ' nd one love',
#  ' sure feel echo dot mani thing need get use ask right question understand',
#  ' thing bare work select rd parti app stuff think could box send mine back asap wast money',
#  ' gift man like plug pictur show cord would prefer cordless still work though purpos bought',
#  ' th echo devic purchas refurbish satisfi time differ tell brand price cheaper echo wake us keep timer play music us act encyclopedia turn light much',
#  ' small echo dot amaz sound come great chang nest thermostat phillip hue light without leav chair',
#  ' talk time song dislik devic',
#  ' never disappoint amazon technolog',
#  ' work promis',
#  ' return echo dot get refund return one packag want refund packag see',
#  ' work',
#  ' weird paus speech pattern present echo devic',
#  ' sure love lol thank great price',
#  ' work',
#  ' echo fan one work',
#  '',
#  ' bought bathroom listen shower love',
#  ' alway respond spoken promp word thought would connect echo upstair use like intercom abl',
#  ' fast ship work well',
#  ' love',
#  ' love love love free assist',
#  ' six word tell poop joke',
#  ' work month stop tri everyth tri make work noth work want refund',
#  ' poor qualiti gave away',
#  ' refurbish way go echo work like',
#  ' love',
#  ' five need say',
#  ' speaker arent loud great though besid naw',
#  ' work great sound good',
#  ' never could get work techi friend look said adapt strong enough power look like bought dollar store go replac adapt hope work',
#  ' almost like star trek fun tri outsmart',
#  ' add echo system refurbish work like',
#  ' great offic use daili mani way includ spell background music',
#  ' awesom love',
#  ' sure realli want one extrem use get one love',
#  ' initi echo dot work well time dot stop respond unless within one foot yell echo echo dot room would respond without respons echo dot would recommend buy refurbish',
#  ' great fast ship',
#  ' bought echo dot refurbish stop whatev function perform quit often wake everi time randomli turn noth buy refurbish echo dot',
#  ' perfect work great problem refurbish',
#  ' dont trust',
#  ' perfect condit love echo',
#  ' love beauti experi especi hook smart light accessori',
#  ' got within last coupl week tell issu son want th birthday could tell joke could ask question listen music enjoy one much bought second one week deal',
#  ' divertido',
#  ' great work great',
#  ' bought guest room radio alarm clock inform center much',
#  ' great buy bought go echo love speaker best music work great timer alarm',
#  '',
#  ' work perfect save buck buy refurbish look brand',
#  ' look work perfect glad got good deal',
#  ' good one bought less',
#  ' love work well',
#  ' everyth perfect',
#  ' good price prompt ship work flawlessli',
#  ' love',
#  ' room improv price complain much still complain howev audio terribl kind like listen speak n spell',
#  ' iov bought son want awesom',
#  ' echo work price great deal issu dot speaker bit tinni good second unit like attach extern speaker sound good buy',
#  ' thank',
#  ' want use radio intercom get terribl fm recept live speech recognit softwar horribl nativ american whose languag english north texa neither accent birth area yet good job understand us bought two thing addit wifi recept poor margin buy wifi rang extend offic ten feet router problem switch around differ disconnect dust collector',
#  ' third dot work perfectli use one multipl time absolut love',
#  ' item never work box broken spent sever day tri get work run fix thing accomplish never order anoth refurbish devic',
#  ' alreadi echo plu bought one love function',
#  ' simpl set music everywher',
#  ' work like brand dot satisfi',
#  ' great return dot refurbish alreadi give problem connect',
#  ' echo alreadi went one refurbish save buck work great love gener one rubber bottom nice',
#  ' love fact unplug take basement want laundri',
#  ' refurbish good one bought',
#  ' good',
#  ' granddaught love',
#  ' price great troubl hear across room move anoth spot seem work fine buy want everi room',
#  ' set blue tooth speaker enjoy listen music outdoor wait tri stuff use',
#  ' thank',
#  ' work great',
#  ' never buy certifi refurbish echo dot bought certifi refurbish echo dot unit poor receiv command sometim even acknowledg command never buy refurbish echo dot unit receiv probabl never certifi refurbish indic also bought echo dot work perfectli disappoint',
#  ' start productsand regret noth absolut great journey product continu improv life',
#  ' use sever month without problem',
#  ' first smart devic sure buy devic compat one',
#  ' love',
#  ' love good one',
#  ' larger echo time love bought one anoth portion sinc sever wifi devic want voic control',
#  ' love use turn light answer quick question',
#  ' great buy',
#  ' leari refurbish work great',
#  ' puni sound work great',
#  ' great',
#  ' exactli like tell differ dot got prior one work perfectli love',
#  ' work perfect wear tear devic love work make smart',
#  ' work good',
#  ' thing like shut work great',
#  ' excel mint condit refurbish unit would never know refurbish',
#  ' alreadi own coupl echo frustrat also use intercom final enabl drop featur use echo reach remot part teenag insist never heard yell come dinner featur mainli use echo standard stuff play music set alarm answer question life chang devic would believ conveni around refurb save buck look work brand one',
#  ' love worri refurbish part first first echo awesom use everyth light sinc work night shop well plan get parent help everyday thing take grant young would recommend everyon',
#  ' love hope everi room soon',
#  ' simplic use set',
#  ' great got one gazebo one upstair',
#  ' work great never issu',
#  ' everyth ask',
#  ' work great good sound',
#  ' use echo listen music well sort research tool answer varieti question would like volum could go littl bit louder complain also believ intern power sourc order use echo must plug time use univers charg cord would nice use echo dot go without buy',
#  ' love great fun',
#  ' love',
#  ' outstand use time work like say',
#  ' save alway nice son alway say buy refurbish mean get devic less run diagnost everyth correct',
#  ' work perfectli turn light tv roomba',
#  ' never would know refurbish',
#  ' far good',
#  ' look perform complaint',
#  ' goe great echo',
#  ' work great like one alreadi',
#  ' item work certifi refurbish mean work advertis instead item crash soon turn plug tri connect phone echo dot crash would disconnect orang would freez thing would reboot blue would tell readi connect freez mid sentenc tri hold action button second anyth return immedi hope actual fix item next buyer purchas',
#  ' fast servic got order thank',
#  ' love even though still tri figur thing item work great phone',
#  ' none',
#  ' echo one bought brand refurbish one honestli tell differ perform look',
#  ' great learn work thing awesom',
#  ' work',
#  ' work time',
#  ' love though wish portabl',
#  ' cours',
#  ' could tell refurbish work excel would highli recommend instead purchas',
#  ' got mom love',
#  ' love echo dot look brand work perfect satisfi',
#  '',
#  ' small problem box rep call walk reset process solv issu shock get respons quickli real effort made includ follow email get thing work one googl clone use learn like also plan instal one car boat garag best friend lol think gf worri learn cook time limit',
#  ' love dot play game son ask weather love work fire tv',
#  ' like could ask differ question differ thing work intermitt smart tv ask chang volum sometim ask chang channel sometim reset know refurbish okay expect',
#  ' far certifi refurbish echo dot work well littl confus green ring echo dot know ask said receiv call drop case took minut figur notif deliveri believ ring suppos yellow pulsat messag notif refurbish echo dot green puls',
#  ' arriv quickli easi set refurbish echo dot beyond expect becom buddi great assist',
#  ' work advertis speak clearli research command also get wall holder keep way set breez make sure close devic initi connect phone reason made set easier though could psycholog haha',
#  ' love two echo dot third one order give gift defect speaker return process still done alreadi taken week',
#  ' alreadi return',
#  ' refurbish echo wonder purchas love abil contact without phone listen music weather ask question wonder gift work excel problem',
#  ' work good howev price went week purchas',
#  ' work amazingli bought love',
#  ' love great help make appoint play song like els look forward',
#  ' got bathroom love listen music whe shower',
#  ' dot origin one work perfectli buy futur dot recondit',
#  ' littl hard get pare other problem',
#  ' weari pick convers activ use heard happen news concern wish would releas someth widespread push firmwar prevent heard yet',
#  ' realli dislik dot thought cortna cool awesom applic unbeliev devic seem aliv must get',
#  ' happi refurbish echo dot two week far work perfectli even though come origin box look like happi purchas',
#  ' thumb',
#  ' workreat',
#  ' someth wrong first one even rep spoke could fix replac regist someon els price dot went price refurbish one bought brand spank one problem one',
#  ' work expect',
#  ' problem',
#  ' almost everi room realli enjoy work perfectli',
#  ' purchas grandson',
#  ' like',
#  ' happi order',
#  ' love dot especi abil talk one realli conveni issu refurbish like',
#  ' start take use sinc unplug one talk lay bed next start go movi moana complet scare sh',
#  ' work great speaker sound fine overal would recommend',
#  ' great like',
#  ' love price essenti brand dot open realli tell refurbish everyth look brand less unit consid better deal realli love versatil echo dot get one',
#  ' pleas order want',
#  ' think throughout conveni set timer check weather whatev wherev',
#  ' love best experi refurbish devic excel',
#  ' love echo dot',
#  ' refurbish item fine awar fee echo set room howev miss cordthank',
#  ' two week set longer work connect sound guess purchas refurbish dot',
#  ' work like brandnew unit great addit collect',
#  ' great price work perfectli save money refurb would buy',
#  '',
#  ' god',
#  ' good',
#  ' great bought one bought anoth right away grab smart switch set smart capabl highli recommend',
#  ' like',
#  ' work still need figur link devic though set sono pretti easi product fault time figur',
#  ' use',
#  ' worst purchas made big fan love brand unlimit digit music video even buy onlin game music movi app tri use make simpl purchas anyth useless',
#  ' work well microphon pick well full size echo audio qualiti okay size',
#  ' bought two refurbish one work work perfectli appear brand',
#  ' disappoint',
#  ' work great bt receiv output connect vintag stereo equip',
#  ' work great far tell edit longev year real test',
#  ' amaz',
#  ' love everyth',
#  ' use dot work fine compliment echo',
#  ' work like one tell differ one bough refurbish one',
#  ' well big fan echo one went bathroom work great expect',
#  ' purchas year old love talk respons detect name room',
#  ' like perform brand one problem',
#  ' echo dot disconnect speaker time buy refurbish star effort',
#  ' love great',
#  ' work good satisfi',
#  ' love sound dot best echo nd gen live room got signific differ sound dot lack full base sound sound come cheap portabl speaker realli disappoint return right away shell money buy second echo also',
#  ' took awhil get connect electron savi love',
#  ' cant seem get thing sink wireless sure return tri one time',
#  ' absolut love',
#  ' stop work return time ran',
#  ' second dot work great refurbishedthought',
#  ' love guy work great',
#  ' love second great check weather medit music timer perfect husband use eye drop multipl time keep eye close minut',
#  ' purchas refurbish work like brand minut set easi echo dot command start play music backyard deck sound system',
#  ' substitut origin echo dot perform well sound qualiti poor listen highest level',
#  ' love echo dot help husband get netflix app fire tv problem refurbish plan get anoth one fire stick',
#  ' stop work month warranti good month would assum sold would higher standard guarante would work whole month mean suppos piec junk offer discount want buy anoth one would want buy anoth one',
#  ' like problem whatsoev thank',
#  ' like uncl sometim goe littl haywir',
#  ' bought son work return',
#  ' bought quit connect wifi respond voic within month hard soft reset fix problem',
#  ' receiv echo dot today good condit advis paid write rais price research buy get good deal set dot went simpl enough plug follow app instruct except initi took actual show iphon wifi set call custom servic dunno late get terribl support guy took call rambl complet unhelp script end set dot middl spiel sure norm refurbish dot pretti finicki wifi rang randomli disconnect even though app show rang ghz connect strong reconnect pain time well said work work amazingli well speaker hook one thing realli enjoy mic rang sensit one annoy limit appl siri play audio devic speaker music podcast hey siri featur useless problem hear whatev play time amazingli fast respons tri louder speaker yet sure continu hold true set control wireless devic breez albeit limit support arlo devic nil special set led devic eg rainbow effect handl know chang solid color bright level rate would lower gotten decent price item connect problem persist may exchang return item want though kind grow',
#  ' bought everyon say much love need use volum loud enough play music treadmil rather use tower speaker xs louder',
#  ' work like',
#  ' second one refurbish model work least',
#  ' bad devic know refurbish activ nobodi talk activ start talk talk yell super laud',
#  ' good like brand save money get one',
#  ' ad room conveni',
#  ' nice work good time easi recogn voic repeat sever time time almost scream',
#  ' took chanc certifi refurbish unit look brand excus disappoint minut troubl free set effortless speaker connect app iphon flawless listen favorit tune bose setup happier walk door ask play music viola instant atmospher open go set turn access pandora app make thing effortless true joy right box discov use fine piec technolog worth everi penni',
#  ' second dot',
#  ' love echo dot two one one refurbish work great becom go sooo mani thing love alarm everi morn whenev love play music sound ocean natur sound tri sleep love mani thing',
#  ' bought refurb work one bought prior came origin packag well',
#  ' love like second',
#  ' far impress save group correctli understand time sure excit alexa voic sound like water suppos understand go return tri googl',
#  ' work well obviou issu refurbish',
#  ' work great tell refurbish set kid mode ad love thing',
#  ' great useless overal mani unnecessari featur unless smart need',
#  ' work good two echo dot precious purchas',
#  ' bought love love guard dog featur say give sens secur night leav',
#  ' bought mainli speaker play music video phone work read instruct work',
#  ' work',
#  ' bought two work great much electron run want need done',
#  ' nd one come',
#  ' blue blink time',
#  ' fun use still learn trick use function futur human interfac household autom like star trek knew would soon',
#  ' work great control tv light variou devic late use wake know time want open eye shout time could figur get hold chore walk dog golden sound great size expect echo plu much better audio get larger expens echo',
#  ' work great',
#  ' sure like littl want one everi room constantli ask spell word bare tap thing capabl look forward learn capabl',
#  '',
#  ' great work well',
#  ' absolutli love',
#  ' bought first echo dot love got work absolut love',
#  ' work promis',
#  ' work great exist smart setup',
#  ' perfect could tell differ one',
#  ' cant figur use',
#  ' good sometim hear well',
#  ' littl apprehens buy refurbish electron guarante thought would tri glad probabl buy anoth refurb form love product sever one sit desk small footprint great sound use daili work great',
#  ' bad bad speaker sound',
#  ' great devic mainli use verbal add thing shop list occasion use number fun thing program like go red alert make tardi land ye geek even chose wake word instead need majel barret voic geek heaven easi get premium work properli still sure get multipl music account attach listen differ music differ room far still worth often ask time weather even give us news brief also use intercom system realli awesom plu fun know nsa listen everyth',
#  ' love',
#  ' purchas love amaz love game',
#  ' alway work',
#  ' good perfectli packag zero issu dot',
#  ' love bought granddaught play music ask question entertain hour good buy honest opinion',
#  ' issu work look great',
#  ' fun toy read',
#  ' refurbish echo dot receiv condit packag complaint neat littl gadget drive nut',
#  ' receiv echo gift love much decid get dot easi set big differ sound qualiti would still buy',
#  ' work advertis thank',
#  ' product great everyth bought refurbish complet garbag never purchas refurbish total dissatisfact',
#  ' work good microphon good better echo product',
#  ' took littl work set final got sound qualiti best got work great check weather ask cook question play radio want music probabl upgrad echo plu better sound',
#  ' love best thing ever bought know ever live thing amaz happi wish would use googl',
#  ' love work great',
#  ' extrem low volum',
#  ' troubl get program download phone end use interest answer come wikipedia howev give echo dot music play depart heard song music total forgotten mainstream station also amus respond know think yard cotton fabric refer footbal play paid full price gadget would sore disappoint seem reason step hal',
#  ' brought replac one move rang previou non refurbish unit would seldom abl find wi fi connect got tire hear messag troubl connect check app unplug went troubleshoot reconnect sever time strong',
#  ' want listen music come sever echo dot unit simultan must pay monthli fee thought appl paid mani could one room enough money',
#  ' purchas gift',
#  ' love',
#  ' overal good devic bought workout room issu reach volum heard standard row machin could use much better speaker',
#  ' work great simpl set way accur imagin im use thought wish alarm could set bit that complaint listen say wake word worri lose conspiraci theori speaker great hold get one turn gen like',
#  ' voic clariti made eavesdrop effort much easier govern',
#  ' work perfect',
#  ' littl troubl begin replac old router work good except current temperatur time much degre like degre would say degre otherwis everyth work expect enjoy listen music pandora station request favorit song record artist',
#  ' bought three three work flawlessli label refurbish known',
#  ' devic work perfectli good price love great fun music great get radio station need morn traffic report think would enjoy ai fun educ entertain even peopl tech savvi',
#  ' eh work half time respond say wake name work fine',
#  ' great littl thing work better siri',
#  ' amaz love',
#  ' bought son love',
#  ' first second gener echo dot think prefer volum ring first gen better button second gen still job great price got still definit recommend',
#  ' fun use morn brief',
#  ' arriv time work amaz',
#  ' like set quick easi',
#  ' like good refurbish',
#  ' love',
#  ' love echo dot',
#  ' like know music type least wireless volum high',
#  ' great',
#  ' work great reason leav star wont play unless plug whole time pretti irrit especi outlet avail',
#  ' work great',
#  ' love ita like person assist everyth els one',
#  ' problem item could inexperi order wrong thing decid set use tri replac small speaker thought could learn go download app never could get echo sync iphon decid give one kid probabl enjoy use intend',
#  ' es perfecto',
#  ' work good far',
#  ' work great love',
#  ' work great',
#  ' love',
#  ' want white dot white bathroom top black shown knew realiz cord plug also black want white cord plug',
#  '',
#  ' work great',
#  ' amaz',
#  ' great',
#  ' work perfectli',
#  ' perfect',
#  ' set echo dot work hour die complet buy refurbish sent back return receiv',
#  ' echo dot horribl volum phone louder devic boss one case',
#  ' overal work well connect issu definit worth money',
#  ' issu refurbish unit perform expect would buy anoth one need',
#  ' great mom insid owlhead jacuzzi',
#  ' work great put son room use drop option get attent game watch tv',
#  ' perfect',
#  ' look brand nrw noth complain defent order',
#  ' ok speaker pretti terribl googl better',
#  ' love',
#  ' love answer stupid question tell weather get couch',
#  ' first one quit work shortli got next one becom unrespons voic time way get work app sure dot way',
#  ' bought go niec room tell refurbish look good work like',
#  ' devic work follow instruct echo dot come upset',
#  ' sent back due crackl nois turn expect refurbish item',
#  ' best price could find use around answer question handi find phone also intercom system',
#  ' never satisfi perfect introduct',
#  ' work well speaker grand get anoth speaker drop futur would gone full size echo',
#  ' love echo thing full size version sound better though',
#  ' work great',
#  ' need life plan time date music',
#  ' seem troubl hear say wake word despit train voic wonder someth buy refurbish googl mini problem hear us much louder',
#  ' love work perfectli',
#  ' brand echo dot thought refurbish would good quit differ expect refurbish unit even turn realiz power adapt faulti way send power adapt accord return option love buy even toilet paper truli let updat contact credit enough buy power adapt shop alway trust deliv product',
#  ' bought gift call see like said love',
#  ' loud qualiti eas use great sound perfect background music would suggest connect togeth tri use host louder parti',
#  ' look brand work great love echo dot refurbish one like',
#  ' nd one use time',
#  ' work like one l anoth devic lm fanat',
#  ' echo good',
#  ' work great',
#  ' great price extend rang super valu dot offer hook wireless speaker use work outsid dot made outdoor sound rang possibl without disturb indoor control possibl',
#  ' amazingli fun ask question first set daili alarm weekend remind playlist morn show random song daili bibl vers weather morn commut tell way go dodg traffic get one link phone yet',
#  ' work perfect differ refurb one one buy refurb',
#  ' great wake everi morn time',
#  ' like differ unus origin',
#  ' complaint far know exactli like littl cheaper great',
#  ' perfect condit',
#  ' like',
#  ' work well version got discount echo speaker decid purchas version state warranti',
#  ' receiv echo gift need anoth someth play music easili access found smart speaker wait see els',
#  ' without use mani featur see use great alarm u r almost deaf hear alarm live room reason enough keep fun ask random question hear respons seem smartbon polit yet',
#  ' think th one purchas work get one everi room realli like featur offer specifili play music echo control light throughout',
#  ' look great',
#  ' love listen song heard sinc childhood get news weather inform great',
#  ' sent year old dad talk constantli',
#  ' love learn knew thing eveyday still figur everyth work far easi use understand make laugh time',
#  ' purchas knee problem give someth tri come get around fast like enjoy littl big thing play song time cook',
#  ' love love love',
#  ' expect',
#  ' love hate',
#  ' realli happi purchas great speaker easi set',
#  ' use coupl day lot fun toy like household tri learn differ featu benefit come',
#  ' love size nd gener echo still need littl improv sound',
#  ' like origin echo shorter greater fabric choic miss volum ring top plu minu button big deal ring w comfort well like use standard usb charger port instead previou round pin guess sound seem work still answer echo like',
#  ' love echo good music sound play understand command difficult time find specif playlist song good music lack major program',
#  ' love use play music play radio itun play podcast anypod set remind listen flash brief news weather everi morn reli custom list like abl voic control volum sure continu find use sometim bit frustrat understand say',
#  ' set day still ad smart devic speaker great play music like size station counter intrus look',
#  ' love play sleep sound immedi ask',
#  ' got second unit expect sound improv didnt realli see differ overal big improv gener',
#  ' amaz',
#  ' love echo easi oper load fun everyth advertis use mainli play favorit tune test knowledg',
#  ' sound great love',
#  ' fun item play get use use sometim hard time answer question ask think better',
#  ' like one',
#  ' still learn capabl far pretti pretti pretti good',
#  ' like',
# ...
#  ' speaker excel sound work perfectli',
#  ' like',
#  ' love everyth',
#  ' littl nervou receiv echo realli tech savvi found bit intimid first take long figur happi purchas think ad echo spot',
#  ' like still learn use',
#  ' great technolog believ speaker volum qualiti wonder wish bought anoth one',
#  ' purchas echo dot husband father use constantli hear qualiti sound echo nd gener brainer best gift ever',
#  ' work fine',
#  '',
#  ' clear music',
#  ' fun use good sound qualiti',
#  ' echo work well abl sync music devic',
#  ' work great think charg anoth cent unlimit music buy echo',
#  ' alreadi echo dot echo even better fuller sound also setup let phone call made contact list great',
#  ' speaker sound realli good',
#  ' good sound work well',
#  ' love savvi support help patient',
#  ' love think get one discount offer could pass fun ask play song group come playlist music also connect iphon play music pandora youtub video use speaker fun ask differ type question inform like weather news even time countri downsid limit data wifi plan use burn play music',
#  ' like far lot tri yet',
#  ' love use strictli music great',
#  ' love echo love size materi speaker qualiti hook one easili work addit light thermostat next echo dot lot echo think traffic weather trivia',
#  ' love',
#  ' entir love echo part',
#  ' great fun get know function wow fun homework help talk grandchildren also echo huge bonu wait learn',
#  ' love',
#  ' awesom thing love',
#  ' work exactli expect speaker great sound perfect classroom',
#  ' love love littl gadget made live much easier like person secretari live hardli need cd anymor sinc play everyth need go get dot soon room thank',
#  ' speaker surpris qualiti happi purchas',
#  ' easi set work wonder love',
#  ' realli impress sound qualiti play music devic bass sound almost like come bigger speaker prop',
#  ' still great sound qualiti seem wors get wrong definit get use within hour definit feel like echo gen sound qualiti better besid great addit abl play wifi even better',
#  ' outlet work disappoint',
#  ' great devic respons help',
#  ' sound terribl u want good music get bose',
#  ' like sound troubl paid extra money access million song sometim work ex play italian song understand play opera tosca respons sorri',
#  ' easi set use bad plug would nice take outsid oper batteri recharg',
#  ' still learn way use real hit grandkid ask play music danc yr cute',
#  ' star gener like great ask like play music set timer make call reason rate sometim connect die echo stop play music show red ring seem connect issu overal great',
#  ' work great upgrad echo dot full size echo happier',
#  ' els say',
#  ' upgrad lilttl echo dot happi sound',
#  ' excel set eas well',
#  ' first gen echo sinc first came work well purchas nd gen far happi seem improv speaker provid enhanc sound music',
#  ' love echo smart speaker love volum clariti easi set wonder gift age',
#  ' wonder fast deliveri',
#  ' initi harder set call tech knowledg work great',
#  ' easi set love',
#  ' great sound respons voic command',
#  ' live long without echo get enjoy music style ask go gread wireless love echo love',
#  ' cool speaker sound good blast',
#  ' much fun love abl listen music across room busi someth els',
#  ' far seem nice item pick voic understand without problem ask turn music next room heard fine use listen music check weather done thing well',
#  ' love echo',
#  ' love help use rememb thing sleep ask anyth week still learn',
#  ' better gen everi way except one realli miss ring top volum control quicker easier grab top twist without look button find one press time also wish bass bit better great devic happi',
#  ' love',
#  ' far like',
#  ' thoroughli enjoy ecoo love read audiobook offic simpli open audiobook kindl continu elsewher wonder listen music mood book great set remind much',
#  ' still love',
#  ' love',
#  ' love sound qualiti unit clear sound',
#  ' listen talk radio morn turn light system excel job full sound system stream siriu',
#  ' week still learn learn process love music call time listen podcast radio station start keep shop list groceri list love search paper pencil get time temperatur great wait weather report sound good fussi woofer tweeter base echo fine afternoon go tri drop son get go surpris',
#  ' much featur',
#  ' great sound qualiti great featur great multi room music cool',
#  ' cool',
#  ' everyon echo two three bought echo qvc',
#  ' annoy everyth show abl download spend much time tri figur phrase machin may well look',
#  ' sinc begin accident spill water replac nd gener decid without echo setup easi work within minut',
#  ' like abl tell alexia music want hear sometim troubl find song specif titl',
#  ' like look better origin echo move old echo basement room nice sound',
#  ' echo wonder still learn use music request somewhat limit',
#  ' know half thing ask recogn sprinkler wifi control even though detail say compat program chang wifi thermostat set match wifi router handi music player music',
#  ' love',
#  ' awesom understand kid',
#  ' pleasantli surpris sound qualiti mani featur nice easili hear particular artist hear book simpl command look forward explor option devic',
#  ' met exceed expect easi set realli quick respons',
#  ' like fact get kind music want request like inform photo littl pamphlet wish includ connect tv command realli love music',
#  ' found way access echo thorough account think part top line video music also think setup app defin exampl music like well integr echo tri ask playlist echo sure even though set play list set also like fact word exact match playlist name never rememb like readi natur echo respond queri',
#  ' great item ad audibl book make even better thank',
#  ' nd gen echo sale resist begin smart set happier say done amaz job connect smart devic thank control light smart plug tv troubl connect echo wifi phone app work perfectli fine let add skill routin smart devic timer much sound qualiti good enough sinc audiophil hear voic even watch movi high volum design great modern definit add nice touch chang cover like sale overal great addit enabl mani possibl yet sure add',
#  ' versatil fun',
#  ' work great killer speaker son love',
#  ' regret wait long purchas item surpris pleas sound qualiti',
#  ' stop work week follow command realli fun work',
#  ' far love work get thing set love groceri list app',
#  ' perform pretti much expect disappoint provid terminolog need play variou kind music without subscrib music servic understand music choic may limit without know ask access music provid free along echo purchas chart show languag need use',
#  ' easi set',
#  ' like except speaker high qualiti expect',
#  ' great invest help made laugh',
#  ' yet anoth exho love',
#  ' love plan gender music big band jazz easi find local radio sound good stop voic command get phone call',
#  ' good valu',
#  ' super easi set love echo',
#  ' what like speaker ask',
#  ' best gift dad joke mom one listen repeat stori go forward',
#  ' great addit breakfast room tune inform instantli avail slowli learn featur',
#  ' sound qualiti',
#  ' sad joke worthless',
#  ' entertain',
#  ' good qualiti',
#  ' work great sound great miss beat wish batteri better portabl',
#  ' love till someon stole afford replac yet go',
#  ' rock',
#  ' got gift love never would bought one allow play music amozon music worth also give brief tell joke',
#  '',
#  ' mom bought echo dot repeat ask take one great told two day made take hour later could live life without amaz four larg speaker small echo dot return say go order speaker go big get echo otherwis tou return two echo dot live without',
#  ' love great',
#  ' easi set user friendli',
#  ' realli disappoint plug wall socket time fault check made assumpt compani technolog advanc would sell recharg batteri could return would appl music boom speaker give flexibl',
#  ' think nd gen sound good aux could add extern speaker go get dot nd issu uniqu unit understand overrid default prevent play blue tooth speaker play group get delay use bt speaker unit heard abl play group use bt speaker',
#  ' everyth',
#  ' like interact ask question like ask setup schedul connect lamp',
#  ' supberb sound definit worth extra money listen lot music',
#  ' realli love echo think sound qualiti great lot fun realli handi music get updat weather sport',
#  ' love grandkid',
#  ' far work well alway intuit link differ devic skill get hang',
#  ' work advertis',
#  ' love',
#  ' love addit speaker qualiti great love two complaint suggest futur seri would better commun abil exampl smart light unless specifi prior command either respond say recogn may want respond say thank afterward repeat thank time respond husband know sound odd laugh mayb southern thing want manner',
#  ' like everyth music trivia game weather',
#  ' describ receiv time like automat enrol music',
#  ' great devic',
#  ' own echo overa year lack easi way increas decreas volum without tell increas decreas volum hard sinc english second languag born korea sound echo superb keep',
#  ' love work well',
#  ' nice impress wish say though',
#  ' love nice easi access much info',
#  ' got great sound bass work time still hot miss recogn thing',
#  ' still discov echo',
#  ' amaz paroduct',
#  ' good hear rang sound qualiti bit complic set quit understand lot even speak slowli clearli love flash brief featur interfac abod secur system',
#  ' speaker sound good',
#  ' absolut love',
#  ' best part control thermostat light anyth dislik',
#  ' thoroughli enjoy echo instal easi use app purchas kasa smart plug control live room light instal easi use kasa app sinqu right echo enjoy play music echo sound qualiti awesom ad kasa smart bulb setup seamless look forward ad autom',
#  ' entertain',
#  ' cool easi setup fun use sound qualiti much better anticip',
#  ' love great sound easi connect use',
#  ' work fairli smart tv mainli tv manufactur lg fault due support anyth older tv year smart lock also need addit piec equip order connect well speaker sound great work well',
#  ' great sound littl speaker',
#  ' enjoy',
#  '',
#  ' cool',
#  ' good qualiti great sound qualiti',
#  ' work perfectli',
#  ' great sometim understand command fire tv fabul speaker',
#  ' love echo great sound smart',
#  ' sure love',
#  ' play great',
#  ' work absolut great',
#  ' amaz great sound qualiti',
#  ' best thing invest thank much',
#  ' extrem impress item bought warehous outlet minor imperfect tell even one work great come packag seal damag miss anyth like sound qualiti see knock bose great easi use minor learn curv learn voic integr seamlessli servic wait get classroom lot fun even speaker let alon plan',
#  ' love echo show wonder music info sleep sound',
#  ' awesom life changer serious abl start morn wake alarm play music gotten use voic anoth room listen say love echo hesit get one price speaker unbeliev buy cordless holder take echo anywher love purchas love',
#  ' super impress laps play anyth smart enough differenti among account use either randomli speak nobodi talk today unplug sure ever use',
#  ' like everyth',
#  ' like',
#  ' never issu buy use electron long get good like read comment see use',
#  ' realli love echo',
#  ' bought love',
#  ' fun got today pod go car use',
#  ' like',
#  ' third echo worth everi penni like household employe small flat rate keep bedroom live room drop use intercom listen music answer quick question alarm wake school',
#  ' listen music set timer',
#  ' receiv echo perfect condit devic easi set respond quickli without issu great addit',
#  ' good sound like music schedul like get random thought record think joke cute',
#  ' purchas begin learn far pleas amaz differ action perform enjoy look forward learn option provid',
#  ' echo great other even though smaller',
#  ' funni buy someth look fun wind total use part love',
#  ' bought replac dot live room speaker slightli better hear better tv unfortun understand respond request well dot frequent request time get want dot usual exactli want first request consid upgrad',
#  ' good experi far second gener echo mani thing learn time yet right mostli enjoy music weather updat use alarm featur person also purchas mini smart socket ye excit begin use',
#  ' troubl connect tv exactli tech smart sure one grandson figur far use mostli music',
#  ' simpli love echo hardli watch tv anymor busi listen music speaker pretti goo size fun skill realli make echo fun whole',
#  ' enjoy entir echo experi',
#  ' easi set',
#  ' echo amaz devic mani time seem intuit time ask someth seem clear simpl get result instal fairli straightforward mess sever time simpli thought step complet actual made lose ground figur advic patient app let know move next step biggest issu moment sever echo devic would like use intercom told done howev make echo awar other exist ask answer instruct chang name know like fault would think design would anticip make easier find need instruct small deal mani devic savvi peopl challeng',
#  ' love much',
#  ' origin tap far nd gener best happi see make improv one would great updat littl think would help lot bug happi play music throughout whole adjust bass trebl thank',
#  ' pleas echo nd gener nice avail music weather news probabl lot discov',
#  ' pleasantli surpris sound qualiti echo big fan deep bass might suffici though potenti control option explor evolv smart voic recognit impress stylish fun regret purchas great technic chang peopl ask play song movi respond instantli elderli love one would great gift connect wifi simpl use want unlimit music control sure premium blown away person dj even convers echo embarrass say echo made laugh coupl time ask tell joke tell packag sinc addict come extrem handi',
#  ' easi setup love thing',
#  ' throughout futur arriv',
#  ' alreadi find today could resist get echo also best thing ever use side happier',
#  ' arriv expect',
#  ' bought week ago everyth excel forget buy charger order must take outsid pool worri hire electrician put outlet yard',
#  ' terrif',
#  ' love echo',
#  ' smaller origin look nicer',
#  ' work great',
#  ' husband would call late adopt come technolog decid would tri echo serv primarili music sourc wow amaz great sound also great time listen favorit song buy ask may even buy one elderli dad think enjoy one listen music even place call us',
#  ' realli enjoy chang directv channel play iheartradio pandora adjust ac thermostat turn live room light outsid light',
#  ' want one bought absolut love',
#  ' glad got echo speaker much stuff non smart speaker person love timer featur help cook multipl thing simultan pandora integr anoth featur use daili happi purchas get echo hub echo dot futur',
#  ' see subject line love',
#  ' love',
#  ' easi setup',
#  ' hesit buy echo echo dot seem good enough echo except sound qualiti realli feel need howev glad got differ sound realli far superior echo dot listen greatest showman littl power',
#  ' sound qualiti great still learn differ thing fun',
#  ' got good deal work great setup bit pain fault crappi internet servic work great nice sound small speaker',
#  ' love',
#  ' work great perfect offic',
#  ' love one insid one pool good bose speaker around',
#  ' easi use amaz',
#  ' nice',
#  ' love echo total amaz speaker qualiti bum buy two sinc got',
#  ' respons great sound qualiti size',
#  ' effici amaz cool use often everi',
#  ' impress qualiti sound echo definit compar bose mini gave star use appl music account',
#  ' technolog small devic price good sound amaz must featur',
#  ' mainli use music learn time realli noth bad say',
#  ' replac gen concern smaller unit sound wrong anyth volum clear good',
#  ' great addit echo plu',
#  ' best',
#  ' love featur play music everi room multipl echo',
#  ' love surpris much use',
#  ' use enjoy love',
#  ' easi use great sound great purchas great price',
#  ' easi set issu',
#  ' unit add much pleasur echo plu music inform one room',
#  ' extrem use simpl thing like audibl thing like sometim answer everyth ask still nice use',
#  ' difficult set keep time enter password',
#  ' get use use echo use shop list listen music timer work great far',
#  ' cool lot fun use week still learn capabl',
#  ' love love',
#  ' love hard time set app',
#  ' use offic anoth apart music inform',
#  ...]

# %%
data['clean_review'] = clean_reviews_list
# Out:
# <ipython-input-19-7f88741bd01a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['clean_review'] = clean_reviews_list

# %%
data
# Out:
#                                        verified_reviews  rating  \
# 0                                         Love my Echo!       5
# 1                                             Loved it!       5
# 2     Sometimes while playing a game, you can answer...       4
# 3     I have had a lot of fun with this thing. My 4 ...       5
# 4                                                 Music       5
# ...                                                 ...     ...
# 3145  Perfect for kids, adults and everyone in betwe...       5
# 3146  Listening to music, searching locations, check...       5
# 3147  I do love these things, i have them running my...       5
# 3148  Only complaint I have is that the sound qualit...       5
# 3149                                               Good       4
#
#                                            clean_review
# 0                                             love echo
# 1                                                  love
# 2      sometim play game answer question correctli s...
# 3      lot fun thing yr old learn dinosaur control l...
# 4                                                 music
# ...                                                 ...
# 3145                          perfect kid adult everyon
# 3146   listen music search locat check time look wea...
# 3147   love thing run entir tv light thermostat fron...
# 3148   complaint sound qualiti great mostli use comm...
# 3149                                               good
#
# [3150 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['rating'] = le.fit_transform(data['rating'])
# Out:
# <ipython-input-23-92ec10a64cd0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['rating'] = le.fit_transform(data['rating'])

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
cv.fit(data['clean_review'])
# Out:
# CountVectorizer()

# %%
sparse_matrix = cv.transform(data['clean_review'])

# %%
sparse_matrix
# Out:
# <3150x2750 sparse matrix of type '<class 'numpy.int64'>'
# 	with 33029 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(sparse_matrix, data['rating'], random_state = 0, test_size = 0.20)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((2520, 2750), (630, 2750), (2520,), (630,))

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()

# %%
nb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = nb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7428571428571429

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 12,   2,   1,   5,  13],
#        [  1,   0,   0,   9,  11],
#        [  2,   0,   5,   9,  23],
#        [  1,   0,   0,  18,  71],
#        [  0,   1,   0,  13, 433]], dtype=int64)
